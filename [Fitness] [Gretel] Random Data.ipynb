# %%
import numpy as np
import pandas as pd

from gretel_synthetics.timeseries_dgan.dgan import DGAN
from gretel_synthetics.timeseries_dgan.config import DGANConfig, OutputType, Normalization

# %%
# Create some random training data data
df = pd.DataFrame(np.random.random(size=(1000,30)))
df.columns = pd.date_range("2022-01-01", periods=30)
# Include an attribute column
df["attribute"] = np.random.randint(0, 3, size=1000)

# %%
df
# Out:
#      2022-01-01 00:00:00  2022-01-02 00:00:00  2022-01-03 00:00:00  \
# 0               0.082317             0.490675             0.512337
# 1               0.969284             0.407557             0.250464
# 2               0.087990             0.475250             0.953025
# 3               0.589374             0.589719             0.924693
# 4               0.159025             0.777289             0.347243
# ..                   ...                  ...                  ...
# 995             0.226364             0.057905             0.251977
# 996             0.043963             0.675363             0.423005
# 997             0.026015             0.825993             0.809734
# 998             0.686875             0.398905             0.765200
# 999             0.903315             0.238820             0.673031
#
#      2022-01-04 00:00:00  2022-01-05 00:00:00  2022-01-06 00:00:00  \
# 0               0.063610             0.977453             0.994126
# 1               0.528988             0.014251             0.914536
# 2               0.270484             0.199150             0.235680
# 3               0.804042             0.194924             0.000023
# 4               0.483097             0.532265             0.692793
# ..                   ...                  ...                  ...
# 995             0.818266             0.478489             0.842181
# 996             0.488241             0.440422             0.785053
# 997             0.330701             0.604350             0.229303
# 998             0.783177             0.876861             0.055325
# 999             0.858669             0.300936             0.841096
#
#      2022-01-07 00:00:00  2022-01-08 00:00:00  2022-01-09 00:00:00  \
# 0               0.097633             0.860585             0.298020
# 1               0.376380             0.818855             0.349281
# 2               0.943064             0.903292             0.185922
# 3               0.841321             0.929569             0.255757
# 4               0.504883             0.392778             0.984852
# ..                   ...                  ...                  ...
# 995             0.608739             0.836188             0.548497
# 996             0.904913             0.093732             0.040903
# 997             0.813932             0.461191             0.937309
# 998             0.775240             0.509410             0.447041
# 999             0.586793             0.880271             0.227000
#
#      2022-01-10 00:00:00  ...  2022-01-22 00:00:00  2022-01-23 00:00:00  \
# 0               0.974638  ...             0.855044             0.619368
# 1               0.726348  ...             0.809160             0.182757
# 2               0.616993  ...             0.443584             0.900717
# 3               0.660317  ...             0.542536             0.154765
# 4               0.451910  ...             0.241943             0.432081
# ..                   ...  ...                  ...                  ...
# 995             0.694302  ...             0.662006             0.089280
# 996             0.024497  ...             0.918087             0.645358
# 997             0.013988  ...             0.291870             0.025354
# 998             0.201433  ...             0.628512             0.000476
# 999             0.234116  ...             0.189145             0.770515
#
#      2022-01-24 00:00:00  2022-01-25 00:00:00  2022-01-26 00:00:00  \
# 0               0.536678             0.720542             0.069560
# 1               0.210798             0.185065             0.092977
# 2               0.348944             0.591567             0.666793
# 3               0.767995             0.947910             0.423636
# 4               0.234921             0.729606             0.683646
# ..                   ...                  ...                  ...
# 995             0.966947             0.197177             0.319839
# 996             0.785092             0.715641             0.259700
# 997             0.406569             0.441630             0.185642
# 998             0.327682             0.291367             0.632583
# 999             0.076629             0.067754             0.970944
#
#      2022-01-27 00:00:00  2022-01-28 00:00:00  2022-01-29 00:00:00  \
# 0               0.811037             0.385888             0.518761
# 1               0.492874             0.388357             0.219685
# 2               0.350914             0.654586             0.949359
# 3               0.439971             0.483036             0.637399
# 4               0.722855             0.171813             0.319271
# ..                   ...                  ...                  ...
# 995             0.556949             0.962358             0.327924
# 996             0.003278             0.870942             0.114180
# 997             0.807025             0.928367             0.491362
# 998             0.160841             0.637687             0.339474
# 999             0.102772             0.809756             0.804297
#
#      2022-01-30 00:00:00  attribute
# 0               0.302822          1
# 1               0.818824          0
# 2               0.465520          0
# 3               0.875752          2
# 4               0.314350          2
# ..                   ...        ...
# 995             0.185473          1
# 996             0.429885          1
# 997             0.942339          1
# 998             0.639800          0
# 999             0.925960          0
#
# [1000 rows x 31 columns]

# %%
# Train the model
model = DGAN(DGANConfig(
    max_sequence_len=30,
    sample_len=3,
    batch_size=1000,
    epochs=10,  # For real data sets, 100-1000 epochs is typical
))

model.train_dataframe(
    df,
    attribute_columns=["attribute"],
    discrete_columns=["attribute"],
)

# Generate synthetic data
synthetic_df = model.generate_dataframe(100)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version. Use is_categorical_dtype instead.
#   elif pd.api.types.is_categorical(cols):
# C:\Users\User\anaconda3\lib\site-packages\category_encoders\one_hot.py:187: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for cat_name, class_ in values.iteritems():
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3340\2695480123.py in <module>
#       7 ))
#       8
# ----> 9 model.train_dataframe(
#      10     df,
#      11     attribute_columns=["attribute"],
#
# ~\anaconda3\lib\site-packages\gretel_synthetics\timeseries_dgan\dgan.py in train_dataframe(self, df, attribute_columns, feature_columns, example_id_column, time_column, discrete_columns, df_style, progress_callback)
#     393         attributes, features = self.data_frame_converter.convert(df)
#     394
# --> 395         self.train_numpy(
#     396             attributes=attributes,
#     397             features=features,
#
# ~\anaconda3\lib\site-packages\gretel_synthetics\timeseries_dgan\dgan.py in train_numpy(self, features, feature_types, attributes, attribute_types, progress_callback)
#     307         )
#     308
# --> 309         self._train(dataset, progress_callback=progress_callback)
#     310
#     311     def train_dataframe(
#
# ~\anaconda3\lib\site-packages\gretel_synthetics\timeseries_dgan\dgan.py in _train(self, dataset, progress_callback)
#     650         drop_last = len(dataset) % self.config.batch_size == 1
#     651
# --> 652         loader = DataLoader(
#     653             dataset,
#     654             self.config.batch_size,
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     260         self.timeout = timeout
#     261         self.worker_init_fn = worker_init_fn
# --> 262         self.multiprocessing_context = multiprocessing_context
#     263
#     264         # Adds forward compatibilities so classic DataLoader can work with DataPipes:
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __setattr__(self, attr, val)
#     422                              'initialized'.format(attr, self.__class__.__name__))
#     423
# --> 424         super().__setattr__(attr, val)
#     425
#     426     # We quote '_BaseDataLoaderIter' since it isn't defined yet and the definition can't be moved up
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in multiprocessing_context(self, multiprocessing_context)
#     399                     valid_start_methods = multiprocessing.get_all_start_methods()
#     400                     if multiprocessing_context not in valid_start_methods:
# --> 401                         raise ValueError(
#     402                             ('multiprocessing_context option '
#     403                              'should specify a valid start method in {!r}, but got '
#
# ValueError: multiprocessing_context option should specify a valid start method in ['spawn'], but got multiprocessing_context='fork'

# %%
synthetic_df
